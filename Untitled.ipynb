# %%
X_train1 = train['Region_California']
y_train1 = train['Starting_Median_Salary']

X_test1  = test['Region_California']
y_test1  = test['Starting_Median_Salary']
#-------------------------------------------
X_train2 = train['Region_Midwestern']
y_train2 = train['Starting_Median_Salary']

X_test2  = test['Region_Midwestern']
y_test2  = test['Starting_Median_Salary']
#-------------------------------------------
X_train3 = train['Region_Northeastern']
y_train3 = train['Starting_Median_Salary']

X_test3  = test['Region_Northeastern']
y_test3  = test['Starting_Median_Salary']
#-------------------------------------------
X_train4 = train['Region_Southern']
y_train4 = train['Starting_Median_Salary']

X_test4 = test['Region_Southern']
y_test4 = test['Starting_Median_Salary']
#------------------------------------------
X_train5 = train['Region_Western']
y_train5 = train['Starting_Median_Salary']

X_test5  = test['Region_Western']
y_test5  = test['Starting_Median_Salary']

# %%
import numpy as np

X_train1 = np.reshape(X_train1, (-1, 1))
y_train1 = np.reshape(y_train1, (-1, 1))

X_test1  = np.reshape(X_test1, (-1, 1))
y_test1  = np.reshape(y_test1, (-1, 1))
#-------------------------------------------
X_train2 = np.reshape(X_train2, (-1, 1))
y_train2 = np.reshape(y_train2, (-1, 1))

X_test2  = np.reshape(X_test2, (-1, 1))
y_test2  = np.reshape(y_test2, (-1, 1))
#-------------------------------------------
X_train3 = np.reshape(X_train3, (-1, 1))
y_train3 = np.reshape(y_train3, (-1, 1))

X_test3  = np.reshape(X_test3, (-1, 1))
y_test3  = np.reshape(y_test3, (-1, 1))
#-------------------------------------------
X_train4 = np.reshape(X_train4, (-1, 1))
y_train4 = np.reshape(y_train4, (-1, 1))

X_test4 = np.reshape(X_test4, (-1, 1))
y_test4 = np.reshape(y_test4, (-1, 1))
#------------------------------------------
X_train5 = np.reshape(X_train5, (-1, 1))
y_train5 = np.reshape(y_train5, (-1, 1))

X_test5  = np.reshape(X_test5, (-1, 1))
y_test5  = np.reshape(y_test5, (-1, 1))

# %%
# California 
linearRegression1 = LinearRegression().fit(X_train1, y_train1)

linearRegression_rmse1 = rmse(y_test1, linearRegression.predict(X_test1))

print(linearRegression_rmse1)

# Midwestern
linearRegression2 = LinearRegression().fit(X_train2, y_train2)

linearRegression_rmse2 = rmse(y_test, linearRegression.predict(X_test2))

print(linearRegression_rmse2)

#Northeastern
linearRegression3 = LinearRegression().fit(X_train3, y_train3)

linearRegression_rmse3 = rmse(y_test, linearRegression.predict(X_test3))

print(linearRegression_rmse3)

#Southern
linearRegression4 = LinearRegression().fit(X_train4, y_train4)

linearRegression_rmse4 = rmse(y_test4, linearRegression.predict(X_test4))

print(linearRegression_rmse4)

#Western
linearRegression5 = LinearRegression().fit(X_train5, y_train5)

linearRegression_rmse5 = rmse(y_test5, linearRegression.predict(X_test5))

print(linearRegression_rmse5)
