# %% [markdown]
# # Where College Pays Off

# %% [markdown]
# ## EDA

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

degrees_df = pd.read_csv('degrees-that-pay-back.csv')
regions_df = pd.read_csv('salaries-by-region.csv')
college_type_df = pd.read_csv('salaries-by-college-type.csv')

# %%
degrees_df
# Out:
#                      Undergraduate Major Starting Median Salary  \
# 0                             Accounting             $46,000.00
# 1                  Aerospace Engineering             $57,700.00
# 2                            Agriculture             $42,600.00
# 3                           Anthropology             $36,800.00
# 4                           Architecture             $41,600.00
# 5                            Art History             $35,800.00
# 6                                Biology             $38,800.00
# 7                    Business Management             $43,000.00
# 8                   Chemical Engineering             $63,200.00
# 9                              Chemistry             $42,600.00
# 10                     Civil Engineering             $53,900.00
# 11                        Communications             $38,100.00
# 12                  Computer Engineering             $61,400.00
# 13                      Computer Science             $55,900.00
# ...

# %%
degrees_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Undergraduate Major                                50 non-null     object
#  1   Starting Median Salary                             50 non-null     object
#  2   Mid-Career Median Salary                           50 non-null     object
#  3   Percent change from Starting to Mid-Career Salary  50 non-null     float64
#  4   Mid-Career 10th Percentile Salary                  50 non-null     object
#  5   Mid-Career 25th Percentile Salary                  50 non-null     object
#  6   Mid-Career 75th Percentile Salary                  50 non-null     object
#  7   Mid-Career 90th Percentile Salary                  50 non-null     object
# dtypes: float64(1), object(7)
# memory usage: 3.2+ KB

# %%
degrees_df.describe()
# Out:
#        Percent change from Starting to Mid-Career Salary
# count                                          50.000000
# mean                                           69.274000
# std                                            17.909908
# min                                            23.400000
# 25%                                            59.125000
# 50%                                            67.800000
# 75%                                            82.425000
# max                                           103.500000

# %%
regions_df
# Out:
#                                          School Name        Region  \
# 0                                Stanford University    California
# 1           California Institute of Technology (CIT)    California
# 2                                Harvey Mudd College    California
# 3                 University of California, Berkeley    California
# 4                                 Occidental College    California
# ..                                               ...           ...
# 315   State University of New York (SUNY) at Potsdam  Northeastern
# 316                               Niagara University  Northeastern
# 317  State University of New York (SUNY) at Fredonia  Northeastern
# 318                     University of Southern Maine  Northeastern
# 319                                    Mercy College  Northeastern
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0               $70,400.00              $129,000.00
# 1               $75,500.00              $123,000.00
# ...

# %%
regions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   School Name                        320 non-null    object
#  1   Region                             320 non-null    object
#  2   Starting Median Salary             320 non-null    object
#  3   Mid-Career Median Salary           320 non-null    object
#  4   Mid-Career 10th Percentile Salary  273 non-null    object
#  5   Mid-Career 25th Percentile Salary  320 non-null    object
#  6   Mid-Career 75th Percentile Salary  320 non-null    object
#  7   Mid-Career 90th Percentile Salary  273 non-null    object
# dtypes: object(8)
# memory usage: 20.1+ KB

# %%
regions_df['Region'].unique()
# Out:
# array(['California', 'Western', 'Midwestern', 'Southern', 'Northeastern'],
#       dtype=object)

# %%
regions_df.describe()
# Out:
#                                       School Name        Region  \
# count                                         320           320
# unique                                        320             5
# top     University of Wisconsin (UW) - Whitewater  Northeastern
# freq                                            1           100
#
#        Starting Median Salary Mid-Career Median Salary  \
# count                     320                      320
# unique                    168                      204
# top                $42,600.00               $72,100.00
# freq                        6                        5
#
#        Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# count                                273                               320
# unique                               166                               217
# top                           $43,300.00                        $67,400.00
# ...

# %%
college_type_df
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 264                  Austin Peay State University        State
# 265                    Pittsburg State University        State
# 266                      Southern Utah University        State
# 267           Montana State University - Billings        State
# 268                  Black Hills State University        State
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0               $72,200.00              $126,000.00
# 1               $75,500.00              $123,000.00
# ...

# %%
college_type_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   School Name                        269 non-null    object
#  1   School Type                        269 non-null    object
#  2   Starting Median Salary             269 non-null    object
#  3   Mid-Career Median Salary           269 non-null    object
#  4   Mid-Career 10th Percentile Salary  231 non-null    object
#  5   Mid-Career 25th Percentile Salary  269 non-null    object
#  6   Mid-Career 75th Percentile Salary  269 non-null    object
#  7   Mid-Career 90th Percentile Salary  231 non-null    object
# dtypes: object(8)
# memory usage: 16.9+ KB

# %%
college_type_df['School Type'].unique()
# Out:
# array(['Engineering', 'Party', 'Liberal Arts', 'Ivy League', 'State'],
#       dtype=object)

# %%
college_type_df.describe()
# Out:
#                                               School Name School Type  \
# count                                                 269         269
# unique                                                249           5
# top     University of Illinois at Urbana-Champaign (UIUC)       State
# freq                                                    2         175
#
#        Starting Median Salary Mid-Career Median Salary  \
# count                     269                      269
# unique                    145                      168
# top                $42,600.00               $72,100.00
# freq                        7                        5
#
#        Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# count                                231                               269
# unique                               141                               178
# top                           $40,100.00                        $54,100.00
# ...

# %%
college_type_df['School Type'].hist()
# Out:
# <AxesSubplot:>

# %%
regions_df['Region'].hist()
# Out:
# <AxesSubplot:>

# %%
macro_df = college_type_df.merge(regions_df, on='School Name')
macro_df = macro_df.iloc[:, 0:9]
macro_df
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 263                  Austin Peay State University        State
# 264                    Pittsburg State University        State
# 265                      Southern Utah University        State
# 266           Montana State University - Billings        State
# 267                  Black Hills State University        State
#
#     Starting Median Salary_x Mid-Career Median Salary_x  \
# 0                 $72,200.00                $126,000.00
# 1                 $75,500.00                $123,000.00
# ...

# %%
macro_df.to_csv('macro_df.csv')

# %%
macro_df['School Type'].hist()
# Out:
# <AxesSubplot:>

# %%
macro_df['Region'].count()
# Out:
# 268

# %%
macro_df.count()
# Out:
# School Name                            268
# School Type                            268
# Starting Median Salary_x               268
# Mid-Career Median Salary_x             268
# Mid-Career 10th Percentile Salary_x    230
# Mid-Career 25th Percentile Salary_x    268
# Mid-Career 75th Percentile Salary_x    268
# Mid-Career 90th Percentile Salary_x    230
# Region                                 268
# dtype: int64

# %%
len(macro_df['School Type'].unique())
# Out:
# 5

# %% [markdown]
# ## Data Cleaning

# %%
macro_df.isnull().sum()
# Out:
# School Name                             0
# School Type                             0
# Starting Median Salary_x                0
# Mid-Career Median Salary_x              0
# Mid-Career 10th Percentile Salary_x    38
# Mid-Career 25th Percentile Salary_x     0
# Mid-Career 75th Percentile Salary_x     0
# Mid-Career 90th Percentile Salary_x    38
# Region                                  0
# dtype: int64

# %%
macro_df = macro_df.dropna()
macro_df.isnull().sum()
# Out:
# School Name                            0
# School Type                            0
# Starting Median Salary_x               0
# Mid-Career Median Salary_x             0
# Mid-Career 10th Percentile Salary_x    0
# Mid-Career 25th Percentile Salary_x    0
# Mid-Career 75th Percentile Salary_x    0
# Mid-Career 90th Percentile Salary_x    0
# Region                                 0
# dtype: int64

# %%
macro_df.rename(columns={'School Name' : 'School_Name',
                         'School Type' : 'School_Type',
                        'Starting Median Salary_x':'Starting_Median_Salary',
                        'Mid-Career Median Salary_x': 'MidCareer_Median_Salary',
                        'Mid-Career 10th Percentile Salary_x': 'MidCareer_10th_Percentile_Salary',
                        'Mid-Career 25th Percentile Salary_x': 'MidCareer_25th_Percentile_Salary',
                        'Mid-Career 75th Percentile Salary_x': 'MidCareer_75th_Percentile_Salary',
                         'Mid-Career 90th Percentile Salary_x': 'MidCareer_90th_Percentile_Salary'},
                inplace=True)
list(macro_df.columns)
# Out:
# /Users/shannonamcchesney/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4298: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# ['School_Name',
#  'School_Type',
#  'Starting_Median_Salary',
#  'MidCareer_Median_Salary',
#  'MidCareer_10th_Percentile_Salary',
#  'MidCareer_25th_Percentile_Salary',
#  'MidCareer_75th_Percentile_Salary',
#  'MidCareer_90th_Percentile_Salary',
#  'Region']

# %%
macro_df.Starting_Median_Salary = macro_df.Starting_Median_Salary.str.strip('$')
macro_df.MidCareer_Median_Salary = macro_df.MidCareer_Median_Salary.str.strip('$')
macro_df.MidCareer_10th_Percentile_Salary = macro_df.MidCareer_10th_Percentile_Salary.str.strip('$')
macro_df.MidCareer_25th_Percentile_Salary = macro_df.MidCareer_25th_Percentile_Salary.str.strip('$')
macro_df.MidCareer_75th_Percentile_Salary = macro_df.MidCareer_75th_Percentile_Salary.str.strip('$')
macro_df.MidCareer_90th_Percentile_Salary= macro_df.MidCareer_90th_Percentile_Salary.str.strip('$')
# Out:
# /Users/shannonamcchesney/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
macro_df
# Out:
#                                       School_Name  School_Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 5           Worcester Polytechnic Institute (WPI)  Engineering
# 6                Carnegie Mellon University (CMU)  Engineering
# 7          Rensselaer Polytechnic Institute (RPI)  Engineering
# ..                                            ...          ...
# 263                  Austin Peay State University        State
# 264                    Pittsburg State University        State
# 265                      Southern Utah University        State
# 266           Montana State University - Billings        State
# 267                  Black Hills State University        State
#
#     Starting_Median_Salary MidCareer_Median_Salary  \
# 0                72,200.00              126,000.00
# 3                62,400.00              114,000.00
# 5                61,000.00              114,000.00
# ...

# %%
macro_df['Starting_Median_Salary'] = macro_df['Starting_Median_Salary'].fillna('').str.replace(',',"").astype(float)
macro_df['MidCareer_Median_Salary'] = macro_df['MidCareer_Median_Salary'].fillna('').str.replace(',',"").astype(float)
macro_df['MidCareer_10th_Percentile_Salary'] = macro_df['MidCareer_10th_Percentile_Salary'].fillna('').str.replace(',',"").astype(float)
macro_df['MidCareer_25th_Percentile_Salary'] = macro_df['MidCareer_25th_Percentile_Salary'].fillna('').str.replace(',',"").astype(float)
macro_df['MidCareer_75th_Percentile_Salary'] = macro_df['MidCareer_75th_Percentile_Salary'].fillna('').str.replace(',',"").astype(float)
macro_df['MidCareer_90th_Percentile_Salary'] = macro_df['MidCareer_90th_Percentile_Salary'].fillna('').str.replace(',',"").astype(float)
# Out:
# /Users/shannonamcchesney/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/shannonamcchesney/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/shannonamcchesney/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
macro_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 230 entries, 0 to 267
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   School_Name                       230 non-null    object
#  1   School_Type                       230 non-null    object
#  2   Starting_Median_Salary            230 non-null    float64
#  3   MidCareer_Median_Salary           230 non-null    float64
#  4   MidCareer_10th_Percentile_Salary  230 non-null    float64
#  5   MidCareer_25th_Percentile_Salary  230 non-null    float64
#  6   MidCareer_75th_Percentile_Salary  230 non-null    float64
#  7   MidCareer_90th_Percentile_Salary  230 non-null    float64
#  8   Region                            230 non-null    object
# dtypes: float64(6), object(3)
# memory usage: 18.0+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(style="white")


corr = macro_df.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True


f, ax = plt.subplots(figsize=(11, 8))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws= {"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Setup the polynomial features
degree = 20
pf = PolynomialFeatures(degree)
lr = LinearRegression()

# Extract the X- and Y- data from the dataframe 
X_data = data[['x']]
Y_data = data['y']

# Create the features and fit the model
X_poly = pf.fit_transform(X_data)
lr = lr.fit(X_poly, Y_data)
Y_pred = lr.predict(X_poly)

# Plot the result
plt.plot(X_data, Y_data, marker='o', ls='', label='data', alpha=1)
plt.plot(X_real, Y_real, ls='--', label='real function')
plt.plot(X_data, Y_pred, marker='^', alpha=.5, label='predictions w/ polynomial features')
plt.legend()
ax = plt.gca()
ax.set(xlabel='x data', ylabel='y data');

# %%
# Mute the sklearn warning about regularization
import warnings
warnings.filterwarnings('ignore', module='sklearn')

from sklearn.linear_model import Ridge, Lasso

# The ridge regression model
rr = Ridge(alpha=0.001)
rr = rr.fit(X_poly, Y_data)
Y_pred_rr = rr.predict(X_poly)

# The lasso regression model
lassor = Lasso(alpha=0.0001)
lassor = lassor.fit(X_poly, Y_data)
Y_pred_lr = lassor.predict(X_poly)

# The plot of the predicted values
plt.plot(X_data, Y_data, marker='o', ls='', label='data')
plt.plot(X_real, Y_real, ls='--', label='real function')
plt.plot(X_data, Y_pred, label='linear regression', marker='^', alpha=.5)
plt.plot(X_data, Y_pred_rr, label='ridge regression', marker='^', alpha=.5)
plt.plot(X_data, Y_pred_lr, label='lasso regression', marker='^', alpha=.5)

plt.legend()

ax = plt.gca()
ax.set(xlabel='x data', ylabel='y data');

# %%
# let's look at the absolute value of coefficients for each model

coefficients = pd.DataFrame()
coefficients['linear regression'] = lr.coef_.ravel()
coefficients['ridge regression'] = rr.coef_.ravel()
coefficients['lasso regression'] = lassor.coef_.ravel()
coefficients = coefficients.applymap(abs)

coefficients.describe()  # Huge difference in scale between non-regularized vs regularized regression

# %%
colors = sns.color_palette()

# Setup the dual y-axes
ax1 = plt.axes()
ax2 = ax1.twinx()

# Plot the linear regression data
ax1.plot(lr.coef_.ravel(), 
         color=colors[0], marker='o', label='linear regression')

# Plot the regularization data sets
ax2.plot(rr.coef_.ravel(), 
         color=colors[1], marker='o', label='ridge regression')

ax2.plot(lassor.coef_.ravel(), 
         color=colors[2], marker='o', label='lasso regression')

# Customize axes scales
ax1.set_ylim(-2e14, 2e14)
ax2.set_ylim(-25, 25)

# Combine the legends
h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2)

ax1.set(xlabel='coefficients',ylabel='linear regression')
ax2.set(ylabel='ridge and lasso regression')

ax1.set_xticks(range(len(lr.coef_)));

# %%
# Get a Pd.Series consisting of all the string categoricals
one_hot_encode_cols = data.dtypes[data.dtypes == np.object]  # filtering by string categoricals
one_hot_encode_cols = one_hot_encode_cols.index.tolist()  # list of categorical fields

# Here we see another way of one-hot-encoding:
# Encode these columns as categoricals so one hot encoding works on split data (if desired)
for col in one_hot_encode_cols:
    data[col] = pd.Categorical(data[col])

# Do the one hot encoding
data = pd.get_dummies(data, columns=one_hot_encode_cols)

# %%
from sklearn.linear_model import LinearRegression

linearRegression = LinearRegression().fit(X_train, y_train)

linearRegression_rmse = rmse(y_test, linearRegression.predict(X_test))

print(linearRegression_rmse)

# %%
from sklearn.linear_model import RidgeCV

alphas = [0.005, 0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 80]

ridgeCV = RidgeCV(alphas=alphas, 
                  cv=4).fit(X_train, y_train)

ridgeCV_rmse = rmse(y_test, ridgeCV.predict(X_test))

print(ridgeCV.alpha_, ridgeCV_rmse)

# %%
f = plt.figure(figsize=(6,6))
ax = plt.axes()

labels = ['Ridge', 'Lasso', 'ElasticNet']

models = [ridgeCV, lassoCV, elasticNetCV]

for mod, lab in zip(models, labels):
    ax.plot(y_test, mod.predict(X_test), 
             marker='o', ls='', ms=3.0, label=lab)


leg = plt.legend(frameon=True)
leg.get_frame().set_edgecolor('black')
leg.get_frame().set_linewidth(1.0)

ax.set(xlabel='Actual Price', 
       ylabel='Predicted Price', 
       title='Linear Regression Results');
